# %%
#SVM Support Vector Machine
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('C:/Users/Nandan/Dropbox/PG-DBDA CDAC Mumbai/ML/Social_Network_Ads.csv')

# %%
dataset
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
X = dataset.iloc[:,:-1].values
y = dataset.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1)

# %%
#Feature scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)

# %%
#Model Building

from sklearn.svm import SVC
model = SVC(kernel='linear',random_state=0)
model1 = model.fit(X_train,y_train)
model1
#Kernel fucntion plays an important role in mapping from
#lower to higher dimension for better classification. Kernel function takes care of the 
#calculations associated with the higher dimensional transformations
# Out:
# SVC(kernel='linear', random_state=0)

# %%
print(model1.predict(sc.transform([[28,83000]])))
# Out:
# [0]

# %%
y_pred = model1.predict(X_test)

# %%
#SVM is used with other ML algorithms to increase their accuracy by mapping to higher dimensions.
#SVM supports non-linear boundaries also

# %%
accuracy_score(y_test,y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_43560\772673080.py in <module>
# ----> 1 accuracy_score(y_test,y_pred)
#
# NameError: name 'accuracy_score' is not defined

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[43,  5],
#        [12, 20]], dtype=int64)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.7875

# %%
#rbf=Radial Basis Function
modelR = SVC(kernel='rbf', random_state=0)
model2 = modelR.fit(X_train, y_train)
model2
# Out:
# SVC(random_state=0)

# %%
y_pred = model2.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.8625

# %%
# SVM can also be used for multi-class classification
# In that case, multiple hyperplanes are used to divide
# regions corresponding to the different classes.
